# %%
# Importa librerías
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Archivo beers.csv:
# * __: row index
# * Abv: the alcoholic content by volume with 0 being no alcohol and 1 being pure alcohol
# * ibu: International bittering units, which describe how bitter a drink is.
# * id:  beers id
# * name:  beer name
# * style: kind of beer
# * brewery_id: brewery id
# * ounces: presentation content
#
# Archivo breweries.csv:
# * __: row index, brewery id
# * name: brewery name
# * city: city of USA
# * state: abbreviation of USA state

# %%
# Cargar una tabla específica del archivo: 
urlfile = 'beers.csv'
urlfile1 = 'breweries.csv'
df_beers = pd.read_csv(urlfile)
df_breweries = pd.read_csv(urlfile1)

# muestre la información del archivo
print(df_beers.info())
print(df_breweries.info())
display(df_beers.head(10))
display(df_breweries.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  558 non-null    int64
#  1   name        558 non-null    object
#  2   city        558 non-null    object
#  3   state       558 non-null    object
# dtypes: int64(1), object(3)
# ...

# %% [markdown]
# * Marca de cerveza con más grados de alcohol y quién la produce?
# * Cervecería que más cervezas tiene en su portafolio? Cuál es la participación de mercado?
# * Distribución de cervezas y estilo por estado o ciudad.Estado | ciudad | compañía | cerveza

# %%
dfe1 = dfe[['IDE', 'IDG', 'profesor', 'jornada', 'nota']]
ind1 = dfe.index.to_list()
dfe1.set_index('IDE', drop=False, inplace=True)
ind2 = dfe.index.to_list()

# %%
df_bb = df_beers.merge(df_breweries, left_on = 'brewery_id', right_on= 'Unnamed: 0')
df_bb.sort_values('abv', inplace=True, ascending = False)
df_bb
# Out:
#       Unnamed: 0_x    abv   ibu  ...                       name_y        city state
# 2278          2278  0.128   NaN  ...      Upslope Brewing Company     Boulder    CO
# 70              70  0.125  80.0  ...    Against the Grain Brewery  Louisville    KY
# 2189          2189  0.120  90.0  ...      Tin Man Brewing Company  Evansville    IN
# 2279          2279  0.104   NaN  ...      Upslope Brewing Company     Boulder    CO
# 1857          1857  0.100  52.0  ...          Sixpoint Craft Ales    Brooklyn    NY
# ...            ...    ...   ...  ...                          ...         ...   ...
# 2186          2186    NaN   NaN  ...  Thunderhead Brewing Company     Kearney    NE
# 2337          2337    NaN   NaN  ...           West Sixth Brewing   Lexington    KY
# 2345          2345    NaN   NaN  ...       Weston Brewing Company      Weston    MO
# 2347          2347    NaN   NaN  ...       Weston Brewing Company      Weston    MO
# ...

# %%
df_bb.groupby(['name_y','name_x'])['city'].describe()
# Out:
#                                                       count unique     top freq
# name_y                    name_x
# 10 Barrel Brewing Company Pub Beer                        1      1    Bend    1
# 18th Street Brewery       Bitter Bitch                    1      1    Gary    1
#                           Black Exodus                    1      1    Gary    1
#                           Cone Crusher                    1      1    Gary    1
#                           Devil's Cup                     1      1    Gary    1
# ...                                                     ...    ...     ...  ...
# Wynkoop Brewing Company   Rail Yard Ale                   1      1  Denver    1
#                           Rail Yard Ale (2009)            1      1  Denver    1
#                           Rocky Mountain Oyster Stout     1      1  Denver    1
#                           Silverback Pale Ale             1      1  Denver    1
# ...
